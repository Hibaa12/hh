# %%
from google .colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dfbd7908-472b-4c5c-b33d-da72cbcd0668" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfbd7908-472b-4c5c-b33d-da72cbcd0668">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
car_data = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
print(car_data)
missing_values = car_data.isnull().sum()
print(missing_values)
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
CARS = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
plt.figure(figsize=(20,6))
sns.lineplot(data=CARS,x = "selling_price",y = "km_driven",hue ="fuel",marker ="o")
plt.title("car selling price vs km driven")
plt.xlabel("selling price")
plt.ylabel("km driven")
plt.grid(True)
plt.show()

# %%
avg_sepal_length = iris.groupby("fuel")["selling_price"].mean().reset_index()
plt.figure(figsize=(8,5))
sns.barplot(data =avg_sepal_length,x="fuel",y="selling_price",palette= "dark")
plt.title("average selling price by fuel")
plt.xlabel("fuel")
plt.ylabel("avg selling price")
plt.show()
# Out:
# <ipython-input-16-f3ac438df01e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data =avg_sepal_length,x="fuel",y="selling_price",palette= "dark")

# %%
plt.figure(figsize=(10,6))
sns.histplot(data =CARS,x="selling_price",hue="fuel",palette = "Set2",bins = 15)
plt.title("distribution of selling price by fuel")
plt.xlabel("selling price")
plt.ylabel("frquency")
plt.show()
